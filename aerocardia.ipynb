# %% [markdown]
# <a href="https://colab.research.google.com/github/AeroCardia-DS/aerocardia/blob/main/aerocardia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import userdata
import os

# Retrieve your secret
token = userdata.get('GITHUB_TOKEN')
username = "AeroCardia-DS"
repo_name = "AeroCardia-DS/aerocardia"

# Define the remote URL with the token for authentication
repo_url = f"https://{username}:{token}@github.com/{repo_name}.git"

# Clone the repository
# !git clone {repo_url}
# %cd {os.path.basename(repo_name)}
# Out:
# Cloning into 'aerocardia'...
# remote: Enumerating objects: 4, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 4 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (4/4), 14.60 KiB | 2.43 MiB/s, done.
# /content/aerocardia

# %%
# %cd {os.path.basename('aerocardia')}
# Out:
# [Errno 2] No such file or directory: 'aerocardia'
# /content/aerocardia
